# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pk
import re 
path = 'd:/Git_Proyects/Tesis/Base_Twitter/'

# %%
citas = []
with open(path+'Tweets_august/citas/muchas_citas_october_medias_1500_T_L.txt', 'r', encoding = 'utf8') as f:
    Lines = f.readlines()                                                                                                   
    for line in Lines:                                                                                                          
        citas.append(line)

# %%
id = 25
Tweets = pd.read_csv(path+f'Tw_1500_citas_55_octubre_todas/Tw_{id}_Cluster_muchas.csv')
print(citas[id])
Tweets
# Out:
# vamos a ocuparnos de sacar del lugar donde han quedado los cinco millones de pobres que macri ha dejado
#                       id                                             Tweets
# 0    1180973158402285569  Si el peronismo mantiene a los pobres en la po...  \
# 1    1183805958587330563  Ahora si que salimos se la pobreza señor pobre...
# 2    1184819923715014656  En definitiva,gracias al peronismo pasamos de ...
# 3    1185392310760157186  Cierto @Gabocbes antes los pobres muertos de h...
# 4    1186091391790833664  Nosotros vamos a ocuparnos de los pobres dice ...
# ..                   ...                                                ...
# 454  1183717027430699010  @LAVOZcomar Totalmente Macri. No quiero volver...
# 455  1183805661613834241  @villitavillagra @etupito Sin hacer nada ya ha...
# 456  1183822489895493632  @populareste Si, va a crear un ministerio más ...
# 457  1183823374700761088  @EfigeniaGauto Macri les sacó plata a los que ...
# ...

# %%
for tw in Tweets['Tweets'][30:40]:
    print(tw)
# Out:
# @sebita_fa @gabicerru Los picos dólares que quedan los van a fugar los del grupo de elite encabezado por macri como vienen haciendo hasta ahora. Nosotros vamos a salir adelante, como siempre lo hicimos.
# AHORA @alferdez "desde el primer día vamos a sacar a los 5 millones de pobres del lugar que macri los ha dejado" #ArgentinaDePie
# #24Oct Alberto Fernández: "Recuperaremos el nivel de los cinco millones de desempleados que dejó Macri en su Gobierno" #EnVivo https://t.co/Tk9BuOWKzK https://t.co/3f2bSlvZcp
# #AlbertoPresidente : "Vamos a sacar de la pobreza a los 5 Millones que deja Macri."
#
# #TodosAMarDelPlata #AlbertoYCristinaEnMardel https://t.co/JbIC6YqYvL
# @FrenteDeTodos @alferdez #Elecciones2019 | Cierre de campaña del @FrenteDeTodos
#
# @alferdez:  "Vamos a ocuparnos de sacar del lugar en el que han quedado los cinco millones de pobres que Macri ha dejado"
# ...

# %%
idds = [8, 21, 24, 31, 32, 48, 66, 71, 79, 80, 82, 97, 116, 125, 133, 196, 207, 208, 261, 272, 281, 283, 288, 331, 341, 404, 445, 467, 470, 565, 628, 634, 637, 691, 703, 736, 745, 799, 858, 880, 908, 921, 947, 948, 1048, 1131, 1135, 1279, 1293, 1302, 1344]
idds2 = [1, 4, 8, 12, 13, 18, 25, 27, 34, 35, 39, 47, 48, 51, 68, 70, 79, 82, 84, 96, 103, 121, 126, 143, 149, 167, 177, 191, 215, 281, 310, 311, 333, 336, 358, 360, 378, 380, 408, 455, 507, 596, 623, 702, 703, 713, 756, 759, 789, 800, 857, 913, 998, 1011, 1037, 1084, 1135, 1155, 1314, 1370, 1390, 1395, 1417]
len(idds2)
# Out:
# 63

# %%
pk.dump(idds2, open(path+'ids_october.pk', 'wb'))
