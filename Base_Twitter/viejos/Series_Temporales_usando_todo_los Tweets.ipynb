# %%
import json
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pickle as pk

# %%
path_git = 'd:/Git_Proyects/Tesis/Base_Twitter/'

nombre = 'kici'

kici_oct = pd.read_csv(path_git+'Tweets_'+nombre+'_oct.csv')
clusters = pk.load(open(path_git+nombre+'_clusters_75_oct.pk', 'rb'))

frases = list(kici_oct['Tweets_sin_url'])
cluster_map = {frases[j]: str(i+1) for i, clus in enumerate(clusters) for j in clus}
kici_oct['cluster'] = kici_oct['Tweets_sin_url'].map(cluster_map)
kici_oct['RT'] = False

# %%
clus_3 = kici_oct[kici_oct['cluster'] == '3']
clus_3
# Out:
#        Unnamed: 0                                             Tweets
# 5390         5390  Axel Kicillof: "Ahora hay gente que se dedica ...  \
# 5434         5434  Axel Kicillof: "Ahora hay gente que se dedica ...
# 5440         5440  La sinceridad de esta frase desnuda la complic...
# 5464         5464  Para Kicillof: “Ahora hay gente que se dedica ...
# 5475         5475  Axel Kicillof: "Ahora hay gente que se dedica ...
# ...           ...                                                ...
# 25980       25980  🇦🇷 ✌️ 🤮 💩  \nAxel Kicillof: "Hay gente que se ...
# 27563       27563  🇦🇷 ✌️ 🤮 💩  \nAxel Kicillof: "Hay gente que se ...
# 34928       34928  Axel Kicillof: "La gente se dedica a vender dr...
# 34930       34930  Axel Kicillof: "La gente se dedica a vender dr...
# 34937       34937  Axel Kicillof: "La gente se dedica a vender dr...
#
#                                 Fecha                     urls  verified
# 5390   Mon Oct 07 02:33:55 +0000 2019  https://t.co/NVpIE0JZaj      True  \
# 5434   Mon Oct 07 02:48:17 +0000 2019  https://t.co/r3iSiR0uw0     False
# 5440   Mon Oct 07 02:47:24 +0000 2019  https://t.co/aRe9GCku20     False
# 5464   Mon Oct 07 02:53:48 +0000 2019                        0     False
# 5475   Mon Oct 07 02:55:18 +0000 2019  https://t.co/EOyDnSRgIb     False
# ...                               ...                      ...       ...
# 25980  Tue Oct 15 15:09:01 +0000 2019  https://t.co/5NieuqiHT4     False
# 27563  Wed Oct 16 18:24:17 +0000 2019  https://t.co/5NieuqiHT4     False
# 34928  Thu Oct 24 19:07:10 +0000 2019  https://t.co/wL3QMz2SU8     False
# 34930  Thu Oct 24 19:13:28 +0000 2019  https://t.co/tmiaKmZBj4     False
# 34937  Thu Oct 24 19:17:53 +0000 2019  https://t.co/SPTazPbwIv     False
#
#                                           Tweets_sin_url cluster     RT
# 5390   Axel Kicillof: "Ahora hay gente que se dedica ...       3  False
# 5434   Axel Kicillof: "Ahora hay gente que se dedica ...       3  False
# 5440   La sinceridad de esta frase desnuda la complic...       3  False
# 5464   Para Kicillof: “Ahora hay gente que se dedica ...       3  False
# 5475   Axel Kicillof: "Ahora hay gente que se dedica ...       3  False
# ...                                                  ...     ...    ...
# 25980  🇦🇷 ✌️ 🤮 💩  \nAxel Kicillof: "Hay gente que se ...       3  False
# 27563  🇦🇷 ✌️ 🤮 💩  \nAxel Kicillof: "Hay gente que se ...       3  False
# 34928  Axel Kicillof: "La gente se dedica a vender dr...       3  False
# 34930  Axel Kicillof: "La gente se dedica a vender dr...       3  False
# 34937  Axel Kicillof: "La gente se dedica a vender dr...       3  False
#
# [443 rows x 8 columns]

# %%
import json

filename = 'd:/Facultad/Tesis/Twitter/201910-kicillof.txt'
tweets_cluster = set(list(clus_3['Tweets']))

# Crea un diccionario para almacenar los tweets originales y sus retweets asociados
retweets_dict = {tweet: [] for tweet in tweets_cluster}

retweets_data = []
with open(filename, 'r', encoding='utf8') as fp:
    for i, line in enumerate(fp):
        json_data = json.loads(line)
        tweet = json_data['text']
        if tweet.startswith('RT'):
            try:
                original_tweet = json_data['retweeted_status']['full_text']
                if original_tweet in tweets_cluster:
                    retweets_dict[original_tweet].append(tweet)
                    filt = clus_3['Tweets'] == original_tweet
                    verifide = clus_3[filt]['verified'].tolist()[0]
                    retweets_data.append({
                        "Tweets": original_tweet,
                        "Fecha": json_data['created_at'],
                        "urls": 0,
                        "verified": verifide,
                        "Tweets_sin_url": original_tweet,
                        "cluster": '3',
                        "RT": True
                    })               
            except KeyError:
                pass

# %%
clus_3.drop(columns=['Unnamed: 0'], inplace=True)
list(clus_3['Tweets'])[20:100]
# Out:
# C:\Users\Ale\AppData\Local\Temp\ipykernel_17164\3509925959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clus_3.drop(columns=['Unnamed: 0'], inplace=True)
# ['Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo".\n\nNo estigmaticemos a los narcos, pobre gente.\n\n  https://t.co/QmiNA0UrRe …',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/wVqpb0mBzB',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/2kiHbvy5Ab',
#  '#EstoVotaste \nAxel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" - https://t.co/xkfP43fZrI',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo".\n\nCorta la bocha: Vidal o los Narcos.',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/cqslCEbeSF',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/G5FItrcRou',
#  '😂😂😂Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/oroV52BtbI',
#  'Axel Kicillof: “Ahora hay gente que se dedica a vender droga porque se quedó sin laburo”... https://t.co/wg1aU877kD',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/0jpOKGs8LB',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" - https://t.co/GKtrSIyQXr',
#  'Axel #Kicillof: "Ahora hay gente que se dedica a vender #droga porque se quedó sin #laburo"',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/jkElaqLwaX',
#  '#Noticias | #Kicillof\n\nAxel Kicillof: “Ahora hay gente que se dedica a vender droga porque perdió el laburo”\n\nLa nota completa acá👇👇\nhttps://t.co/qxvkZZZ7tg',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/QGlMms31lS',
#  'Perfil | Axel Kicillof: "La gente se dedica a vender droga porque se quedó sin laburo" https://t.co/ZKRa0WwQng https://t.co/6tcufgcdXY',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/osaCY8IQm7',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/ojeAPgj9Oa',
#  'Axel Kicillof: "La gente se dedica a vender droga porque se quedó sin laburo" https://t.co/M9GZfBp5HY',
#  'Acá lo tenes al sore........Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" - https://t.co/BKsr4hMRn0',
#  'Axel Kicillof: "La gente se dedica a vender droga porque se quedó sin laburo" https://t.co/hI9w6HABCT',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/ZB4HCBcTVM',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/x2h3ukSdMe',
#  'Axel Kicillof: “Ahora hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/QTykso68IH',
#  'Q pensas de lo que dijo Axel Kicillof?  TE leemos con #Novaresio910 : “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/dNE74yVuI9',
#  'TE leemos con #Novaresio910 Axel Kicillof: La gente se dedica a vender droga porque se quedó sin laburo https://t.co/IZ1Msv6XV8',
#  'Nooooo!!!!Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/Ni093JI3P8',
#  '😱 \n\nAxel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo"',
#  "Axel Kicillof: 'La gente se dedica a vender droga porque se quedó sin laburo' https://t.co/6bfWOGGDVO",
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/7aOlAfHhC8',
#  'No tenes filtro. Contale a los familiares de los que viven este flagelo que es porque no hay laburo @PatoBullrich @edufeiok que opinan?\n\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/Ebj1v7tvb8',
#  'Que peligrosa justificación..\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/yiJoUNtQc8',
#  'Perfil | Axel Kicillof: "La gente se dedica a vender droga porque se quedó sin laburo" https://t.co/VvhV8s9O0t',
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/Qg4H9leWwR',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/evDGoMg9Lz',
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/9mq7hg4eLR',
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo”, dijo Kicillof https://t.co/jchlAbUO45',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/PCDQUoTLLu',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/Vq2Ij3V2dy',
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/TrFTJgM8CL',
#  'Actualizamos: Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/6dbMhfDrqi https://t.co/uOl2pqyQ40',
#  'Dice Axel Kicillof que "La gente se dedica a vender droga porque se quedó sin laburo"... https://t.co/nyhKKiEIER https://t.co/6TvegYu3VG',
#  'Listo. \nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/cUgBxUSxzp',
#  'No es chiste: según Kicillof, hay gente que vende drogas porque se quedó sin laburo https://t.co/rsi87thSjm',
#  'Dijo Axel Kicillof que "la gente se dedica a vender droga porque se quedó sin laburo".\n#ChauUber',
#  '“Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/lPzZgQLL7x',
#  'Kicillof afirmó que hay gente que vende droga "porque se quedó sin laburo" - https://t.co/vx8eM7Pl0Y https://t.co/7sGDu3YxpU',
#  'Y si, buscar un oficio, ofrecer cortar pasto, barrer una vereda es ilegal, no?\n Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/XEzgpUUQ1P',
#  'Esto nos espera en la provincia, todavía estamos a tiempo... NO A Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/uVD0Vpq4LG',
#  'Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo\x94: \n      Ayer el candidato... https://t.co/NAON2B0Mkf',
#  'Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/itpDlyy3Tp https://t.co/3slp0mPzep',
#  'Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/7nKW7d6rpH https://t.co/AW3FREv9kq',
#  'Q PENSAS?   Te leemos con #Novaresio910 Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/dNE74yVuI9',
#  'Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/iIPSkN7cH7',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/BPdLwixZiR',
#  'SON LOS VAGOS COMO VOS @AxelKicillof18 ESOS. La gente decente busca laburo, NO VENDE DROGA. @luisnovaresio PATÉTICO.\n     Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/QHIDU8j31W',
#  '🤦\u200d♀️🤦\u200d♀️. Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/uRisnzLyvJ',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/Bz1LusMBeL https://t.co/OWuh2oKgsm',
#  'iProfesional | Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/rLjJ4Oc3HX https://t.co/mevQ5tVENG',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/j6l14Gm4rj',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/aqIyyOIMdi',
#  'Horror!\nAxel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/HCK35lCdHu',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae ES INDIVIDUO HACE APOLOGÍA DEL DELITO! NO SE PUEDE CREER!  https://t.co/ihOmlyFnnh',
#  'Axel Kicillof: “Ahora hay gente que se dedica a vender droga porque se quedó sin laburo”\nhttps://t.co/fTBDypSZ9c https://t.co/qeC51C0Nxo',
#  'No enano pelotudo, es porque son K! \n\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” \nhttps://t.co/Qfp8w1ecrZ',
#  'Mas bruto no se consigue. Dios no libre y guarde de este tipo gobernando a Bs As\n\n#YOVOTOVIDAL\n\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/xBSYWBh741',
#  'Lo que viene !!! ... lo que viene !!!\n\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/gDBE6Udl3W',
#  'Sin palabras ..... vota bien //////.   Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" - https://t.co/6AqnT0Z1b9',
#  'Axel Kicillof: “Ahora hay gente que se dedica a vender droga porque se quedó sin laburo”. 🙄 Notable definición...',
#  'Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/pcXa478gxC vía @LANACION',
#  'Hay gente que se dedica a matar a otra porque se quedó sin trabajo...\nAxel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/cU9sviVZh3',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” https://t.co/R0BsS7gAUG',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/gExwQev5ig',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/zahq3NofUU',
#  '⚠️ Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedo sin laburo " https://t.co/VPUOOEFf9E',
#  'Huy y esa gente es kirchnerista Axel? Tiene todo permitido?\nAxel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo” - Infobae https://t.co/NHIPK3zpbe',
#  'Axel Kicillof: "Hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/QBmIuUgB3h',
#  'Axel Kicillof: "Ahora hay gente que se dedica a vender droga porque se quedó sin laburo" https://t.co/gh2WAl3iPF',
#  'Kirchenerismo en estado puro: Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/rGWdq2xn9J',
#  'Axel Kicillof: “Hay gente que se dedica a vender droga porque se quedó sin laburo”  https://t.co/sHxc8MB4U0']

# %%
len(retweets_data)
df_RT = pd.DataFrame(retweets_data)
clus_3_completo = pd.concat([clus_3, df_RT], ignore_index=True)
#clus_3_completo

# %%
clus_3_completo['Fecha'] = pd.to_datetime(clus_3_completo['Fecha'], format='%a %b %d %H:%M:%S +0000 %Y')
horas = '6H'
#ventana_temporal = pd.offsets.Hour(horas)
clus_3_verifide =  clus_3_completo[clus_3_completo['verified']== True]
clus_3_user =  clus_3_completo[clus_3_completo['verified']== False]

dos_tipos =[clus_3_verifide, clus_3_user]
names = ['verificados', 'usuarios']
plt.figure()

for i, tipos in enumerate(dos_tipos):
    df_grouped = tipos.groupby(pd.Grouper(key='Fecha', freq=horas)).size().reset_index(name='count')
    plt.plot(df_grouped['Fecha'], df_grouped['count'], marker='o', linestyle='-', label = names[i])

# df_grouped = clus_3_completo.groupby(pd.Grouper(key='Fecha', freq=horas)).size().reset_index(name='count')
# plt.plot(df_grouped['Fecha'], df_grouped['count'], marker='o', linestyle='-', label = 'completo')
plt.title("Tweets y RT ventana 6hs")
plt.xlabel('Fecha y hora')
plt.ylabel('Cantidad de elementos')
#plt.xlim([datetime(2019, 10, 26), datetime(2019, 10, 30)])
plt.yscale('log')
plt.legend()
plt.grid(alpha = 0.7)
plt.xticks(rotation=45)
plt.show()
